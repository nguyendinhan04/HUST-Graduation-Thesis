# %%
# %pip install byteplus-python-sdk-v2

# %%
import os
# Install SDK:  pip install byteplus-python-sdk-v2 
from byteplussdkarkruntime import Ark 
import dotenv

dotenv.load_dotenv("../../.env")

# Initialize Ark Client
client = Ark(
    # The base URL for model invocation
    base_url="https://ark.ap-southeast.bytepluses.com/api/v3", 
    # Get API Key：https://console.byteplus.com/ark/region:ark+ap-southeast-1/apikey
    api_key=os.getenv('ARK_API_KEY'), 
)

completion = client.chat.completions.create(
    # Replace with Model ID
    model = "auto",
    messages=[
        {"role": "user", "content": "Please extract all IT skills in the following text in BIO format:Phối hợp với đội ngũ UI/UX để chuyển đổi wireframe thiết kế thành mã nguồn thực tế, tạo ra các yếu tố giao diện trực quan cho ứng dụng. Xây dựng cầu nối giữa thiết kế đồ họa và triển khai kỹ thuật, đảm nhận vai trò chủ động ở cả hai khía cạnh: ứng dụng trông như thế nào và hoạt động ra sao. Tham gia phát triển và duy trì các ứng dụng web sử dụng ReactJS, Next.js. Làm việc cùng các kỹ sư và lập trình viên ở các lớp hạ tầng khác nhau, cam kết giải quyết vấn đề hiệu quả, thiết kế tinh tế và tạo ra sản phẩm chất lượng cao. Hỗ trợ toàn bộ vòng đời ứng dụng (ý tưởng, thiết kế, kiểm thử, phát hành, hỗ trợ). Viết mã sạch, tối ưu để tạo ra sản phẩm web hoàn chỉnh và dễ bảo trì. Thu thập yêu cầu nghiệp vụ, đề xuất giải pháp phù hợp. Viết unit test và UI test để xác định và khắc phục lỗi. Debug, tối ưu hiệu năng ứng dụng. Thiết kế giao diện tăng trải nghiệm người dùng. Phối hợp với đội phát triển sản phẩm để lên kế hoạch cho các tính năng mới. Đảm bảo các ứng dụng mới và cũ đều đạt tiêu chuẩn chất lượng. Nghiên cứu, đề xuất các sản phẩm web, ứng dụng và giao thức mới. Cập nhật xu hướng công nghệ mới."},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ArkNotFoundError                          Traceback (most recent call last)
# Cell In[3], line 16
#       8 # Initialize Ark Client
#       9 client = Ark(
#      10     # The base URL for model invocation
#      11     base_url="https://ark.ap-southeast.bytepluses.com/api/v3",
#      12     # Get API Key：https://console.byteplus.com/ark/region:ark+ap-southeast-1/apikey
#      13     api_key=os.getenv('ARK_API_KEY'),
#      14 )
# ---> 16 completion = client.chat.completions.create(
#      17     # Replace with Model ID
#      18     model = "auto",
#      19     messages=[
# ...

# %% [markdown]
# Phát triển, tùy biến các module trên nền tảng Odoo (phiên bản CE hoặc EE) theo yêu cầu của doanh nghiệp. Làm việc với Business Analyst (BA) để phân tích yêu cầu, hiểu quy trình nghiệp vụ và đề xuất giải pháp. Tích hợp Odoo với các hệ thống bên ngoài qua API (REST, XML-RPC…). Tham gia vào quá trình migrate dữ liệu từ hệ thống cũ lên Odoo (product master data, kho, tài chính, khách hàng…). Fix bug, bảo trì hệ thống và hỗ trợ người dùng trong quá trình vận hành. Viết tài liệu kỹ thuật, hỗ trợ bàn giao và đào tạo người dùng.	Nam/Nữ - Từ 23 tuổi trở lên Tốt nghiệp Đại học/Cao đẳng CNTT, Khoa học máy tính hoặc chuyên ngành liên quan. Từ 3 năm kinh nghiệm lập trình Odoo hoặc có kinh nghiệm triển khai ERP Có kinh nghiệm tùy biến các module: Sales, Purchase, Inventory, Accounting, Manufacturing, CRM, HR… là lợi thế. Biết cách tạo và quản lý module Odoo custom. Ưu tiên ứng viên có kinh nghiệm migrate Odoo hoặc triển khai Odoo v14 – v18 Thành thạo Python, hiểu kiến trúc MVC và ORM của Odoo. Có kiến thức tốt về PostgreSQL, XML, JavaScript, HTML/CSS. Đọc hiểu tài liệu kỹ thuật tiếng Anh. Tư duy logic tốt, khả năng đọc hiểu nghiệp vụ và làm việc nhóm hiệu quả. Khả năng tự học, cập nhật công nghệ nhanh. Kỹ năng làm việc nhóm và phối hợp liên phòng ban.	Lương & thưởng: Thu nhập cạnh tranh, xét tăng lương định kỳ, - thưởng lễ/tết, thưởng hiệu quả công việc. Bảo hiểm: Được tham gia đầy đủ BHXH, BHYT, BHTN theo quy định pháp luật. Phúc lợi: Nghỉ lễ, phép năm, hiếu hỉ, sinh nhật, team building, du lịch hằng năm. Môi trường làm việc: Chuyên nghiệp, thân thiện, cơ hội học hỏi và phát triển bản thân. Đào tạo & phát triển: Được tham gia các chương trình đào tạo nội bộ/bên ngoài nâng cao kỹ năng, chuyên môn. Cơ hội thăng tiến: Rõ ràng, minh bạch theo năng lực và kết quả công việc.

# %%
completion = client.chat.completions.create(
    # Replace with Model ID
    model = "seed-2-0-lite-260228",
    messages=[
        {"role": "user", "content": "Please extract all IT skills in the following text and list in format - Skill 1, Skill 2, Skill 3 and keep raw text, do not translate:'Phát triển, tùy biến các module trên nền tảng Odoo (phiên bản CE hoặc EE) theo yêu cầu của doanh nghiệp. Làm việc với Business Analyst (BA) để phân tích yêu cầu, hiểu quy trình nghiệp vụ và đề xuất giải pháp. Tích hợp Odoo với các hệ thống bên ngoài qua API (REST, XML-RPC…). Tham gia vào quá trình migrate dữ liệu từ hệ thống cũ lên Odoo (product master data, kho, tài chính, khách hàng…). Fix bug, bảo trì hệ thống và hỗ trợ người dùng trong quá trình vận hành. Viết tài liệu kỹ thuật, hỗ trợ bàn giao và đào tạo người dùng.	Nam/Nữ - Từ 23 tuổi trở lên Tốt nghiệp Đại học/Cao đẳng CNTT, Khoa học máy tính hoặc chuyên ngàn`h liên quan. Từ 3 năm kinh nghiệm lập trình Odoo hoặc có kinh nghiệm triển khai ERP Có kinh nghiệm tùy biến các module: Sales, Purchase, Inventory, Accounting, Manufacturing, CRM, HR… là lợi thế. Biết cách tạo và quản lý module Odoo custom. Ưu tiên ứng viên có kinh nghiệm migrate Odoo hoặc triển khai Odoo v14 – v18 Thành thạo Python, hiểu kiến trúc MVC và ORM của Odoo. Có kiến thức tốt về PostgreSQL, XML, JavaScript, HTML/CSS. Đọc hiểu tài liệu kỹ thuật tiếng Anh. Tư duy logic tốt, khả năng đọc hiểu nghiệp vụ và làm việc nhóm hiệu quả. Khả năng tự học, cập nhật công nghệ nhanh. Kỹ năng làm việc nhóm và phối hợp liên phòng ban.'."},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# - Odoo, API, REST, XML-RPC, ERP, Python, MVC, ORM, PostgreSQL, XML, JavaScript, HTML/CSS

# %%
Skill 1: Odoo, Skill 2: REST, Skill 3: XML-RPC, Skill 4: ERP, Skill 5: Python, Skill 6: MVC, Skill 7: Odoo ORM, Skill 8: PostgreSQL, Skill 9: XML, Skill 10: JavaScript, Skill 11: HTML/CSS

# %% [markdown]
# Chịu trách nhiệm phát triển Backend & Frontend cho các ứng dụng trong lĩnh vực Logistic, Fintech, E-Learning,... sử dụng công nghệ .Net, Python, JavaScript, TypeScript, bao gồm: Dựng khung cho ứng dụng Backend, Frontend đảm bảo yếu tố dễ maintain và tái sử dụng cho nhiều dự án (với vị trí Senior hoặc Middle) Dựng UI cho ứng dụng theo thiết kế UI/UX/Wireframes Viết API cho các ứng dụng frontend (web, mobile) theo chuẩn RESTful, GraphQL Xây dựng ứng dụng responsive, tương thích với đa trình duyệt, SEO-Friendly, tối ưu hóa về mặt băng thông và bộ nhớ Viết tài liệu mô tả chức năng Viết Unit tests Đảm bảo các công việc được giao thực hiện đúng thời hạn và chất lượng tốt. Phối hợp, hỗ trợ thành viên trong dự án hoàn thành công việc chung của dự án. Nghiên cứu các công nghệ theo hướng dẫn của trưởng nhóm

# %%
completion = client.chat.completions.create(
    # Replace with Model ID
    model = "seed-2-0-lite-260228",
    messages=[
        {"role": "user", "content": "Extract all IT skills in the following text and list in format - Skill, Skill, Skill"
        " keep raw text, do not translate:"
        ""
        "'Chịu trách nhiệm phát triển Backend & Frontend cho các ứng dụng trong lĩnh vực Logistic, Fintech, E-Learning,... sử dụng công nghệ .Net, Python, JavaScript, TypeScript, bao gồm: Dựng khung cho ứng dụng Backend, Frontend đảm bảo yếu tố dễ maintain và tái sử dụng cho nhiều dự án (với vị trí Senior hoặc Middle) Dựng UI cho ứng dụng theo thiết kế UI/UX/Wireframes Viết API cho các ứng dụng frontend (web, mobile) theo chuẩn RESTful, GraphQL Xây dựng ứng dụng responsive, tương thích với đa trình duyệt, SEO-Friendly, tối ưu hóa về mặt băng thông và bộ nhớ Viết tài liệu mô tả chức năng Viết Unit tests Đảm bảo các công việc được giao thực hiện đúng thời hạn và chất lượng tốt. Phối hợp, hỗ trợ thành viên trong dự án hoàn thành công việc chung của dự án. Nghiên cứu các công nghệ theo hướng dẫn của trưởng nhóm'."},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# Backend, Frontend, .Net, Python, JavaScript, TypeScript, UI, UI/UX, Wireframes, API, RESTful, GraphQL, SEO, Unit tests

# %%
completion = client.chat.completions.create(
    # Replace with Model ID
    model = "seed-2-0-lite-260228",
    messages=[
        {"role": "user", "content": "Extract all IT skills in the following text and list in format - Skill, Skill, Skill"
        " keep raw text, do not translate:"
        ""
        "'FPT Software HCM đang tìm kiếm các bạn sinh viên đã/sắp tốt nghiệp để tham gia vào các dự án phát triển phần mềm quy mô lớn. Tham gia khóa đào tạo chuyên sâu về lập trình Java/Python/MS Azure/MS Fabric & AI Foundry (Data & AI service trên Azure Cloud ) từ 3-6 tháng: Cơ hội trở thành lập trình viên chuyên nghiệp sau Khóa đào tạo lập trình tại FPT Software. Chương trình đào tạo chuyên nghiệp, được đúc kết từ kinh nghiệm làm việc thực tế trong các dự án lớn với các tập đoàn lớn trên thế giới. Cơ hội trở thành lập trình viên chuyên nghiệp sau Khóa đào tạo lập trình tại FPT Software.	Là sinh viên sắp ra trường/mới ra trường học ngành Công nghệ Thông tin, Kỹ thuật Phần mềm,.. hoặc các chuyên ngành liên quan,… Nắm vững kiến thức Lập trình hướng đối tượng (OOP), SQL, Java Core, Python,… Có khả năng đọc hiểu và giao tiếp tiếng Anh tốt, tương đương Toeic 700+ trở lên Có thể làm việc full time từ thứ 2- thứ 6 (8h00-17h00).'"},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# lập trình Java, Python, MS Azure, MS Fabric & AI Foundry, Lập trình hướng đối tượng (OOP), SQL, Java Core

# %%
completion = client.chat.completions.create(
    # Replace with Model ID
    model = "seed-2-0-lite-260228",
    messages=[
        {"role": "user", "content": "Extract all IT skills in the following text"
        "Rule:"
        " 1.keep raw text, do not translate:"
        "2.Format output: Skill, Skill, Skill"
        "Text:'Xây dựng hoặc duy trì ứng dụng web và các trang web dựa trên thiết kế, thông số kỹ thuật được cung cấp. Làm việc với quản lý dự án để nâng cao trải nghiệm người dùng và các vấn đề về giao diện. Phát triển Web chạy trên nhiều trình duyệt và tích hợp đa nền tảng. Chuyển các yêu cầu ứng dụng sang ứng dụng ổn định, hoạt động, hiệu suất cao. Làm việc chặt chẽ với các thành viên của nhóm dự án để đảm bảo tất cả các thông số kỹ thuật được thỏa mãn. Các công việc khác theo sự phân công của Quản lý trực tiếp/Trưởng bộ phận.	Tốt nghiệp Đại học/Cao đẳng các chuyên ngành Công nghệ thông tin, Kỹ thuật phần mềm… hoặc các chuyên ngành liên quan khác. Có ít nhất 2 năm kinh nghiệm lập trình Web, nắm rõ một thư viện/framework như ReactJS, AngularJS hoặc VueJS. Kiến thức vững chắc về Javascript, Typescript và kinh nghiệm làm việc với HTML5, CSS3. Hiểu biết về RESTful API và có kinh nghiệm tích hợp vào các ứng dụng Web trên desktop và mobile. Kinh nghiệm tốt trong việc xây dựng ứng dụng Web SPA (Single Page Application), có kinh nghiệm lập trình với sự hỗ trợ của AI là một lợi thế. Kiến thức tốt về kiến trúc và thuận toán; kinh nghiệm thiết kế UI/UX là một lợi thế. Tinh thần học hỏi tốt; khả năng chịu áp lực trong công việc cao.'"},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# - lập trình Web, ReactJS, AngularJS, VueJS, Javascript, Typescript, HTML5, CSS3, RESTful API, SPA (Single Page Application), lập trình với sự hỗ trợ của AI, kiến trúc và thuận toán, thiết kế UI/UX

# %%
completion = client.chat.completions.create(
    # Replace with Model ID
    model = "seed-2-0-lite-260228",
    messages=[
        {"role": "user", "content": "Extract all IT skills in the following text and list in format - Skill, Skill, Skill"
        " keep raw text, do not translate:"
        ""
        "'1. INTRODUCTION Founded in 2010, Ban Vien Corporation has embarked on an inspiring journey, evolving into a trusted technology partner that has left an indelible mark in the realm of software development and embedded system development. Today, our influence extends both domestically and internationally, showcasing our commitment to driving digital transformation. At Ban Vien, we relentlessly pursue innovation across diverse industries like Edutech, Fintech, Retail, Automotive, Smart IoT, and Logistics. Our comprehensive services span Digital Consulting, R&D, Software Development, and Dedicated Development Centers. This global expansion includes valued clients and esteemed partners in the United States, Germany, Japan, Singapore, China, Hong Kong, Thailand, Malaysia, and Vietnam. 2.KEY RESPONSIBILITIES Develop and maintain embedded software using C, C++, or Embedded C Perform unit testing, test coverage, and verification activities Work with Matlab/Ascet models for software design or implementation Conduct debugging using emulators, simulators, and test equipment Collaborate on ECU testing and CAN-based communication validation Automate test scripts and processes using Python or Excel Troubleshoot issues related to embedded systems and hardware interfaces	3.REQUIRED SKILLS & EXPERIENCE Strong knowledge of embedded systems, microcontrollers, and processors Experience in Embedded Software Development (Embedded C / C++ programming) Good understanding of CAN communication, COM Stack. Familiarity with debugging and hardware test equipment Experience with unit testing and validation processes Knowledge of Software Development Life-cycle (V-model) Problem-solving mindset with automation awareness Nice to Have: Experience with Classic AUTOSAR architecture Exposure to ECU testing OS programming concepts (interrupt management, OS scheduling) Experience with Matlab / Ascet model-based development Strong scripting skills (Python, Excel automation)'"},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# - software development, embedded system development, C, C++, Embedded C, unit testing, test coverage, verification, Matlab, Ascet, debugging, emulators, simulators, ECU testing, CAN-based communication validation, Python, Excel, embedded systems, hardware interfaces, microcontrollers, processors, CAN communication, COM Stack, hardware test equipment, Software Development Life-cycle (V-model), automation, Classic AUTOSAR architecture, OS programming, interrupt management, OS scheduling, model-based development, scripting skills, Excel automation

# %%
extracted_skills = "software development, embedded system development, C, C++, Embedded C, unit testing, test coverage, verification, Matlab, Ascet, debugging, emulators, simulators, ECU testing, CAN-based communication validation, Python, Excel, embedded systems, hardware interfaces, microcontrollers, processors, CAN communication, COM Stack, hardware test equipment, Software Development Life-cycle (V-model), automation, Classic AUTOSAR architecture, OS programming, interrupt management, OS scheduling, model-based development, scripting skills, Excel automation"

extracted_skills_list = [skill.strip() for skill in extracted_skills.split(",")]

print(extracted_skills_list)



raw_jd = '1. INTRODUCTION Founded in 2010, Ban Vien Corporation has embarked on an inspiring journey, evolving into a trusted technology partner that has left an indelible mark in the realm of software development and embedded system development. Today, our influence extends both domestically and internationally, showcasing our commitment to driving digital transformation. At Ban Vien, we relentlessly pursue innovation across diverse industries like Edutech, Fintech, Retail, Automotive, Smart IoT, and Logistics. Our comprehensive services span Digital Consulting, R&D, Software Development, and Dedicated Development Centers. This global expansion includes valued clients and esteemed partners in the United States, Germany, Japan, Singapore, China, Hong Kong, Thailand, Malaysia, and Vietnam. 2.KEY RESPONSIBILITIES Develop and maintain embedded software using C, C++, or Embedded C Perform unit testing, test coverage, and verification activities Work with Matlab/Ascet models for software design or implementation Conduct debugging using emulators, simulators, and test equipment Collaborate on ECU testing and CAN-based communication validation Automate test scripts and processes using Python or Excel Troubleshoot issues related to embedded systems and hardware interfaces	3.REQUIRED SKILLS & EXPERIENCE Strong knowledge of embedded systems, microcontrollers, and processors Experience in Embedded Software Development (Embedded C / C++ programming) Good understanding of CAN communication, COM Stack. Familiarity with debugging and hardware test equipment Experience with unit testing and validation processes Knowledge of Software Development Life-cycle (V-model) Problem-solving mindset with automation awareness Nice to Have: Experience with Classic AUTOSAR architecture Exposure to ECU testing OS programming concepts (interrupt management, OS scheduling) Experience with Matlab / Ascet model-based development Strong scripting skills (Python, Excel automation)'



# get the position of each skill in the raw JD text in format  [(start,end)]
skill_positions = []
for skill in extracted_skills_list:
    start = raw_jd.find(skill)
    if start != -1:
        end = start + len(skill)
        skill_positions.append((start, end))
for skill, position in zip(extracted_skills_list, skill_positions):
    print(f"Skill: {skill}, Position: {position}")
# Out:
# ['software development', 'embedded system development', 'C', 'C++', 'Embedded C', 'unit testing', 'test coverage', 'verification', 'Matlab', 'Ascet', 'debugging', 'emulators', 'simulators', 'ECU testing', 'CAN-based communication validation', 'Python', 'Excel', 'embedded systems', 'hardware interfaces', 'microcontrollers', 'processors', 'CAN communication', 'COM Stack', 'hardware test equipment', 'Software Development Life-cycle (V-model)', 'automation', 'Classic AUTOSAR architecture', 'OS programming', 'interrupt management', 'OS scheduling', 'model-based development', 'scripting skills', 'Excel automation']
# Skill: software development, Position: (9, 29)

# %%
completion = client.chat.completions.create(
    # Replace with Model ID
    model = "seed-2-0-lite-260228",
    messages=[
        {"role": "user", "content": "Extract all IT skills in the following text"
        "Rule:"
        " 1.keep raw text, do not translate:"
        "2.Format output: Skill, Skill, Skill"
        "Text:'Phát triển .NET phục vụ hệ thống Headend và các nền tảng IPTV/OTT của FPT Play. Tham gia triển khai hệ thống MultiDRM cho platform OTT (Android, iOS, Smart TV), bao gồm tích hợp API, xử lý luồng mã hoá nội dung (DRM packaging), và tối ưu hiệu năng. Quản lý & vận hành hệ thống Headend cấp tín hiệu cho nền tảng IPTV và OTT – FPT Play: Xây dựng công cụ tự động hóa (bằng .NET hoặc script) để giám sát, cảnh báo, tối ưu luồng Headend. Thu phát kênh từ chảo vệ tinh, từ các Đài Truyền hình Thu phát các chương trình sự kiện live, hỗ trợ sản xuất chương trình trực tiếp Thực hiện các nhiệm vụ khác theo phân công của Quản lý.	Tốt nghiệp Đại học/Cao đẳng nghành công nghệ thông tin hoặc liên quan. Có khả năng code Python/.NET, API, Web frontend cơ bản, sử dụng Git. Network: CCNA cơ bản Có khả năng vận hành hệ thống Linux, cài đặt và cấu hình: + Database: SQLServer, MySQL, ... + Container: Docker, Kubernetes + Storage, DNS Service, Web service, Proxy'"},
    ],
    # thinking={"type": "disabled"}, #  Manually disable deep thinking
)
print(completion.choices[0].message.content)
# Out:
# .NET, Headend, IPTV, OTT, MultiDRM, Android, iOS, Smart TV, API, DRM packaging, Python, Web frontend, Git, CCNA, Linux, SQLServer, MySQL, Docker, Kubernetes, Storage, DNS Service, Web service, Proxy

# %%
extracted_skills = ".NET, Headend, IPTV, OTT, MultiDRM, Android, iOS, Smart TV, API, DRM packaging, Python, Web frontend, Git, CCNA, Linux, SQLServer, MySQL, Docker, Kubernetes, Storage, DNS Service, Web service, Proxy"

extracted_skills_list = [skill.strip() for skill in extracted_skills.split(",")]

print(extracted_skills_list)



raw_jd = 'Phát triển .NET phục vụ hệ thống Headend và các nền tảng IPTV/OTT của FPT Play. Tham gia triển khai hệ thống MultiDRM cho platform OTT (Android, iOS, Smart TV), bao gồm tích hợp API, xử lý luồng mã hoá nội dung (DRM packaging), và tối ưu hiệu năng. Quản lý & vận hành hệ thống Headend cấp tín hiệu cho nền tảng IPTV và OTT – FPT Play: Xây dựng công cụ tự động hóa (bằng .NET hoặc script) để giám sát, cảnh báo, tối ưu luồng Headend. Thu phát kênh từ chảo vệ tinh, từ các Đài Truyền hình Thu phát các chương trình sự kiện live, hỗ trợ sản xuất chương trình trực tiếp Thực hiện các nhiệm vụ khác theo phân công của Quản lý.	Tốt nghiệp Đại học/Cao đẳng nghành công nghệ thông tin hoặc liên quan. Có khả năng code Python/.NET, API, Web frontend cơ bản, sử dụng Git. Network: CCNA cơ bản Có khả năng vận hành hệ thống Linux, cài đặt và cấu hình: + Database: SQLServer, MySQL, ... + Container: Docker, Kubernetes + Storage, DNS Service, Web service, Proxy'



import re

# get the position of each skill in the raw JD text in format  [(start,end)]
# Handles multiple occurrences using regex
skill_positions = []
for skill in extracted_skills_list:
    # Use re.escape to handle special characters in skill names like .NET
    # finditer returns an iterator yielding match objects for all non-overlapping matches
    matches = list(re.finditer(re.escape(skill), raw_jd))
    positions = [(m.start(), m.end()) for m in matches]
    skill_positions.append(positions)

for skill, positions in zip(extracted_skills_list, skill_positions):
    print(f"Skill: {skill}, Positions: {positions}")
# Out:
# ['.NET', 'Headend', 'IPTV', 'OTT', 'MultiDRM', 'Android', 'iOS', 'Smart TV', 'API', 'DRM packaging', 'Python', 'Web frontend', 'Git', 'CCNA', 'Linux', 'SQLServer', 'MySQL', 'Docker', 'Kubernetes', 'Storage', 'DNS Service', 'Web service', 'Proxy']
# Skill: .NET, Positions: [(11, 15), (370, 374), (717, 721)]
# Skill: Headend, Positions: [(33, 40), (277, 284), (424, 431)]
# Skill: IPTV, Positions: [(57, 61), (311, 315)]
# Skill: OTT, Positions: [(62, 65), (131, 134), (319, 322)]
# Skill: MultiDRM, Positions: [(109, 117)]
# Skill: Android, Positions: [(136, 143)]
# Skill: iOS, Positions: [(145, 148)]
# Skill: Smart TV, Positions: [(150, 158)]
# Skill: API, Positions: [(178, 181), (723, 726)]
# Skill: DRM packaging, Positions: [(212, 225)]
# Skill: Python, Positions: [(710, 716)]
# Skill: Web frontend, Positions: [(728, 740)]
# Skill: Git, Positions: [(757, 760)]
# Skill: CCNA, Positions: [(771, 775)]
# Skill: Linux, Positions: [(813, 818)]
# Skill: SQLServer, Positions: [(853, 862)]
# ...
